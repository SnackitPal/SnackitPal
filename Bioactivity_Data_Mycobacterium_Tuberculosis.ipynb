# %% [markdown]
# <a href="https://colab.research.google.com/github/SnackitPal/SnackitPal/blob/main/Bioactivity_Data_Mycobacterium_Yuberculosis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery**
#
# Sanket Palve
#
# Thanks to Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 818.4 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 3.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Mycobacterium tuberculosis**

# %%
# Target search for Mycobacterium tuberculosis
target = new_client.target
target_query = target.search('mycobacterium tuberculosis')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#     cross_references                                      organism  \
# 0                 []                    Mycobacterium tuberculosis
# 1                 []              Mycobacterium tuberculosis H37Rv
# 2                 []      Mycobacterium tuberculosis variant bovis
# 3                 []    Mycobacterium tuberculosis variant microti
# 4                 []  Mycobacterium tuberculosis variant bovis BCG
# ..               ...                                           ...
# 106               []                    Mycobacterium tuberculosis
# 107               []                    Mycobacterium tuberculosis
# 108               []                    Mycobacterium tuberculosis
# 109               []                    Mycobacterium tuberculosis
# 110               []                    Mycobacterium tuberculosis
#
#                                         pref_name  score  species_group_flag  \
# 0                      Mycobacterium tuberculosis   27.0               False
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the first entry (which corresponds to the target organism, *Mycobacterium tuberculosis*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL360'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Mycobacterium tuberculosis* (CHEMBL360) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#      action_type activity_comment  activity_id  \
# 0           None             None       347357
# 1           None             None       364157
# 2           None   Not Determined       948666
# 3           None   Not Determined       952655
# 4           None   Not Determined       955268
# ...          ...              ...          ...
# 2817        None             None     25113094
# 2818        None             None     25113095
# 2819        None             None     25113096
# 2820        None             None     25113100
# 2821        None             None     25113135
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL747092
# 1                                                    []    CHEMBL747092
# 2                                                    []    CHEMBL748922
# 3                                                    []    CHEMBL748922
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('mycobacterium_tuberculosis_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-9-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#      action_type activity_comment  activity_id  \
# 0           None             None       347357
# 1           None             None       364157
# 10          None             None       970553
# 11          None             None       971946
# 15          None             None       979154
# ...          ...              ...          ...
# 2817        None             None     25113094
# 2818        None             None     25113095
# 2819        None             None     25113096
# 2820        None             None     25113100
# 2821        None             None     25113135
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL747092
# 1                                                    []    CHEMBL747092
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1815

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      action_type activity_comment  activity_id  \
# 0           None             None       347357
# 1           None             None       364157
# 10          None             None       970553
# 11          None             None       971946
# 15          None             None       979154
# ...          ...              ...          ...
# 2816        None             None     25113093
# 2817        None             None     25113094
# 2818        None             None     25113095
# 2819        None             None     25113096
# 2821        None             None     25113135
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL747092
# 1                                                    []    CHEMBL747092
# 10                                                   []    CHEMBL748921
# 11                                                   []    CHEMBL748921
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL47882   C=CCNC(=S)Nc1ccc(-c2nnc(SCc3ccc(Cl)cc3Cl)n2C)cc1
# 1          CHEMBL374478  CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(c(/C...
# 10         CHEMBL175244            CCCCCCCCCCSc1ncnc2c1ncn2CC(=O)OC(C)(C)C
# 11         CHEMBL177834                CCCCCCCCCCCCSc1ncnc2c1ncn2CC(=O)OCC
# 15         CHEMBL369695                  CCCCCCCCCCSc1ncnc2c1ncn2CC(=O)OCC
# ...                 ...                                                ...
# 2816      CHEMBL5177297        O=C(/C=C/c1nccs1)N1CCN(Cc2ccc3c(c2)OCO3)CC1
# 2817      CHEMBL5277032                           CCSc1nc(NC)c2cccc(F)c2n1
# 2818      CHEMBL5290063                              CCSc1nc(NC)c2ccccc2n1
# 2819      CHEMBL5270552                             CCNc1nc(SCC)nc2ccccc12
# 2821      CHEMBL4097528  CCOC(=O)c1c(NC(=O)c2c(F)c(F)c(F)c(F)c2F)sc2c1C...
#
#      standard_value
# 0              10.0
# 1             147.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('mycobacterium_tuberculosis_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('mycobacterium_tuberculosis_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL47882   C=CCNC(=S)Nc1ccc(-c2nnc(SCc3ccc(Cl)cc3Cl)n2C)cc1
# 1          CHEMBL374478  CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(c(/C...
# 2          CHEMBL175244            CCCCCCCCCCSc1ncnc2c1ncn2CC(=O)OC(C)(C)C
# 3          CHEMBL177834                CCCCCCCCCCCCSc1ncnc2c1ncn2CC(=O)OCC
# 4          CHEMBL369695                  CCCCCCCCCCSc1ncnc2c1ncn2CC(=O)OCC
# ...                 ...                                                ...
# 1810      CHEMBL5177297        O=C(/C=C/c1nccs1)N1CCN(Cc2ccc3c(c2)OCO3)CC1
# 1811      CHEMBL5277032                           CCSc1nc(NC)c2cccc(F)c2n1
# 1812      CHEMBL5290063                              CCSc1nc(NC)c2ccccc2n1
# 1813      CHEMBL5270552                             CCNc1nc(SCC)nc2ccccc12
# 1814      CHEMBL4097528  CCOC(=O)c1c(NC(=O)c2c(F)c(F)c(F)c(F)c2F)sc2c1C...
#
#       standard_value         class
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('mycobacterium_tuberculosis_bioactivity_data_curated.csv', index=False)

# %%
! zip mycobacterium_tuberculosis.zip *.csv
# Out:
#   adding: mycobacterium_tuberculosis_bioactivity_data_curated.csv (deflated 82%)
#   adding: mycobacterium_tuberculosis_bioactivity_data_preprocessed.csv (deflated 80%)
#   adding: mycobacterium_tuberculosis_bioactivity_data_raw.csv (deflated 93%)

# %%
! ls -l
# Out:
# total 2092
# -rw-r--r-- 1 root root  154314 Sep  8 05:05 mycobacterium_tuberculosis_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  137873 Sep  8 05:04 mycobacterium_tuberculosis_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 1674416 Sep  8 05:02 mycobacterium_tuberculosis_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  166879 Sep  8 05:07 mycobacterium_tuberculosis.zip
# drwxr-xr-x 1 root root    4096 Sep  5 17:47 sample_data

# %%
from google.colab import files
files.download('mycobacterium_tuberculosis_bioactivity_data_curated.csv')

# %% [markdown]
# ---
